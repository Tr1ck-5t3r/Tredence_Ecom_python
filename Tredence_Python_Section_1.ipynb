# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Section 1: Data Preprocessing and Descriptive Statistics

# %% [markdown]
# ### 1.1 Data Loading and Inspection

# %%
orders = pd.read_csv("modded/df_Orders.csv")
customers = pd.read_csv("modded/df_Customers.csv")
payments = pd.read_csv("modded/df_Payments_new.csv")
order_items = pd.read_csv("modded/df_OrderItems_new.csv")
products=pd.read_csv("modded/df_Products_new.csv")

# %%
orders
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 0      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1      v6px92oS8cLG  PxA7fv9spyhx    delivered      2018-06-20 21:40:31
# 2      Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered      2018-02-16 16:19:31
# 3      bwJVWupf2keN  EOEsCQ6QlpIg    delivered      2018-08-18 18:04:29
# 4      Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered      2017-12-22 16:44:04
# ...             ...           ...          ...                      ...
# 89311  zlcLnXGgAabl  bfJtzkBGksdY    delivered      2018-08-19 17:25:36
# 89312  IlTAoIkILwrq  4hjsCpj6FC7g    delivered      2017-12-15 11:20:27
# 89313  uA6oXfftGVmT  DLn56oKHl9bv    delivered      2018-07-24 06:39:14
# 89314  v3QtU6xlGDJp  auSfRYUQUOIq    delivered      2018-08-11 08:04:22
# 89315  Xo1fqyXOC6CR  rhevVNXYJnEs    delivered      2018-06-09 21:46:58
#
#          order_approved_at order_delivered_timestamp  \
# 0      2017-10-22 19:14:13       2017-10-26 22:19:52
# 1      2018-06-20 22:20:20       2018-07-03 22:51:22
# 2      2018-02-17 16:15:35       2018-02-27 01:29:50
# 3      2018-08-18 18:15:16       2018-08-27 20:03:51
# 4      2017-12-22 17:31:31       2018-01-05 19:22:49
# ...                    ...                       ...
# 89311  2018-08-21 04:35:30       2018-08-30 14:47:46
# 89312  2017-12-16 02:37:32       2017-12-20 19:23:40
# 89313  2018-07-24 11:20:39       2018-07-27 01:41:40
# 89314  2018-08-11 08:24:40       2018-08-14 21:43:51
# 89315  2018-06-09 22:19:00       2018-06-14 15:03:46
#
#       order_estimated_delivery_date
# 0                        2017-11-09
# 1                        2018-07-24
# 2                        2018-03-08
# 3                        2018-09-19
# 4                        2018-01-18
# ...                             ...
# 89311                    2018-09-04
# 89312                    2018-01-04
# 89313                    2018-08-01
# 89314                    2018-08-17
# 89315                    2018-07-05
#
# [89316 rows x 7 columns]

# %%
customers
# Out:
#         customer_id  customer_zip_code_prefix       customer_city  \
# 0      hCT0x9JiGXBQ                     58125     varzea paulista
# 1      PxA7fv9spyhx                      3112  armacao dos buzios
# 2      g3nXeJkGI0Qw                      4119             jandira
# 3      EOEsCQ6QlpIg                     18212          uberlandia
# 4      mVz5LO2Vd6cL                     88868            ilhabela
# ...             ...                       ...                 ...
# 89311  bfJtzkBGksdY                     94060              amparo
# 89312  4hjsCpj6FC7g                     99835             itapevi
# 89313  DLn56oKHl9bv                      2540           sao paulo
# 89314  auSfRYUQUOIq                     12288            paulinia
# 89315  rhevVNXYJnEs                     93048            brasilia
#
#       customer_state
# 0                 SP
# 1                 RJ
# 2                 SP
# 3                 MG
# 4                 SP
# ...              ...
# 89311             SP
# 89312             SP
# 89313             SP
# 89314             SP
# 89315             DF
#
# [89316 rows x 4 columns]

# %%
products
# Out:
#          product_id     category  sub_category  stock_quantity
# 0      90K0C1fIyQUf         toys          misc              13
# 1      qejhpMGGVcsl      watches         gifts               3
# 2      qUS5d2pEAyxJ  costruction  tools garden               5
# 3      639iGvMyv0De         toys          misc               6
# 4      1lycYGcsic2F         toys          misc              13
# ...             ...          ...           ...             ...
# 89311  W8vikEizUggJ         toys          misc               1
# 89312  KXSbyJWtMMwZ         toys          misc               3
# 89313  EG4wDSpFyTth       health        beauty             206
# 89314  ZWyg4uNWPHjJ         toys          misc             110
# 89315  5pbzE0rDy61l         toys          misc               1
#
# [89316 rows x 4 columns]

# %%
payments
# Out:
#            order_id  payment_sequential payment_type  installments  \
# 0      Axfy13Hk4PIk                   1  credit_card             1
# 1      v6px92oS8cLG                   1  credit_card             8
# 2      Ulpf9skrhjfm                   1  credit_card             4
# 3      bwJVWupf2keN                   1  credit_card             2
# 4      Dd0QnrMk9Cj5                   1  credit_card             1
# ...             ...                 ...          ...           ...
# 89311  zlcLnXGgAabl                   1       wallet             1
# 89312  IlTAoIkILwrq                   1       wallet             1
# 89313  uA6oXfftGVmT                   1  credit_card             1
# 89314  v3QtU6xlGDJp                   1      voucher             1
# 89315  Xo1fqyXOC6CR                   1  credit_card            10
#
#        payment_value payment_status
# 0             259.14           paid
# 1             382.39           paid
# 2             249.25           paid
# 3              27.79           paid
# 4              76.15           paid
# ...              ...            ...
# 89311         128.00           paid
# 89312         106.86           paid
# 89313         376.39           paid
# 89314          48.05           paid
# 89315         211.93           paid
#
# [89316 rows x 6 columns]

# %%
order_items
# Out:
#            order_id    product_id     seller_id    price  freight_value  \
# 0      Axfy13Hk4PIk  90K0C1fIyQUf  ZWM05J9LcBSF   223.51          84.65
# 1      v6px92oS8cLG  qejhpMGGVcsl  IjlpYfhUbRQs   170.80          23.79
# 2      Ulpf9skrhjfm  qUS5d2pEAyxJ  77p2EYxcM9MD    64.40          17.38
# 3      bwJVWupf2keN  639iGvMyv0De  jWzS0ayv9TGf   264.50          30.72
# 4      Dd0QnrMk9Cj5  1lycYGcsic2F  l1pYW6GBnPMr   779.90          30.66
# ...             ...           ...           ...      ...            ...
# 89311  zlcLnXGgAabl  W8vikEizUggJ  2QjevWskirjm    31.99         188.65
# 89312  IlTAoIkILwrq  KXSbyJWtMMwZ  BFS9XJPapWv0   282.00           1.64
# 89313  uA6oXfftGVmT  EG4wDSpFyTth  TuPm19CMKvrM    58.10           4.09
# 89314  v3QtU6xlGDJp  ZWyg4uNWPHjJ  yGbPyLPc8PmT  2899.00         113.01
# 89315  Xo1fqyXOC6CR  5pbzE0rDy61l  mkWN70fui2ro    37.88          70.06
#
#        quantity
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ...         ...
# 89311         1
# 89312         1
# 89313         1
# 89314         1
# 89315         1
#
# [89316 rows x 6 columns]

# %%
customers.drop_duplicates(inplace=True)
order_items.drop_duplicates(inplace=True)
products.drop_duplicates(inplace=True)
payments.drop_duplicates(inplace=True)
orders.drop_duplicates(inplace=True)

# %%
orders
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 0      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1      v6px92oS8cLG  PxA7fv9spyhx    delivered      2018-06-20 21:40:31
# 2      Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered      2018-02-16 16:19:31
# 3      bwJVWupf2keN  EOEsCQ6QlpIg    delivered      2018-08-18 18:04:29
# 4      Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered      2017-12-22 16:44:04
# ...             ...           ...          ...                      ...
# 89311  zlcLnXGgAabl  bfJtzkBGksdY    delivered      2018-08-19 17:25:36
# 89312  IlTAoIkILwrq  4hjsCpj6FC7g    delivered      2017-12-15 11:20:27
# 89313  uA6oXfftGVmT  DLn56oKHl9bv    delivered      2018-07-24 06:39:14
# 89314  v3QtU6xlGDJp  auSfRYUQUOIq    delivered      2018-08-11 08:04:22
# 89315  Xo1fqyXOC6CR  rhevVNXYJnEs    delivered      2018-06-09 21:46:58
#
#          order_approved_at order_delivered_timestamp  \
# 0      2017-10-22 19:14:13       2017-10-26 22:19:52
# 1      2018-06-20 22:20:20       2018-07-03 22:51:22
# 2      2018-02-17 16:15:35       2018-02-27 01:29:50
# 3      2018-08-18 18:15:16       2018-08-27 20:03:51
# 4      2017-12-22 17:31:31       2018-01-05 19:22:49
# ...                    ...                       ...
# 89311  2018-08-21 04:35:30       2018-08-30 14:47:46
# 89312  2017-12-16 02:37:32       2017-12-20 19:23:40
# 89313  2018-07-24 11:20:39       2018-07-27 01:41:40
# 89314  2018-08-11 08:24:40       2018-08-14 21:43:51
# 89315  2018-06-09 22:19:00       2018-06-14 15:03:46
#
#       order_estimated_delivery_date
# 0                        2017-11-09
# 1                        2018-07-24
# 2                        2018-03-08
# 3                        2018-09-19
# 4                        2018-01-18
# ...                             ...
# 89311                    2018-09-04
# 89312                    2018-01-04
# 89313                    2018-08-01
# 89314                    2018-08-17
# 89315                    2018-07-05
#
# [89316 rows x 7 columns]

# %%
customers
# Out:
#         customer_id  customer_zip_code_prefix       customer_city  \
# 0      hCT0x9JiGXBQ                     58125     varzea paulista
# 1      PxA7fv9spyhx                      3112  armacao dos buzios
# 2      g3nXeJkGI0Qw                      4119             jandira
# 3      EOEsCQ6QlpIg                     18212          uberlandia
# 4      mVz5LO2Vd6cL                     88868            ilhabela
# ...             ...                       ...                 ...
# 89311  bfJtzkBGksdY                     94060              amparo
# 89312  4hjsCpj6FC7g                     99835             itapevi
# 89313  DLn56oKHl9bv                      2540           sao paulo
# 89314  auSfRYUQUOIq                     12288            paulinia
# 89315  rhevVNXYJnEs                     93048            brasilia
#
#       customer_state
# 0                 SP
# 1                 RJ
# 2                 SP
# 3                 MG
# 4                 SP
# ...              ...
# 89311             SP
# 89312             SP
# 89313             SP
# 89314             SP
# 89315             DF
#
# [89316 rows x 4 columns]

# %%
products
# Out:
#          product_id     category  sub_category  stock_quantity
# 0      90K0C1fIyQUf         toys          misc              13
# 1      qejhpMGGVcsl      watches         gifts               3
# 2      qUS5d2pEAyxJ  costruction  tools garden               5
# 3      639iGvMyv0De         toys          misc               6
# 4      1lycYGcsic2F         toys          misc              13
# ...             ...          ...           ...             ...
# 89291  USSzekoHkA25         toys          misc               1
# 89297  SZRgDV7xa2U8         toys          misc               1
# 89303  w2OtdEjwNHBr         toys          misc               1
# 89311  W8vikEizUggJ         toys          misc               1
# 89315  5pbzE0rDy61l         toys          misc               1
#
# [27451 rows x 4 columns]

# %%
payments
# Out:
#            order_id  payment_sequential payment_type  installments  \
# 0      Axfy13Hk4PIk                   1  credit_card             1
# 1      v6px92oS8cLG                   1  credit_card             8
# 2      Ulpf9skrhjfm                   1  credit_card             4
# 3      bwJVWupf2keN                   1  credit_card             2
# 4      Dd0QnrMk9Cj5                   1  credit_card             1
# ...             ...                 ...          ...           ...
# 89311  zlcLnXGgAabl                   1       wallet             1
# 89312  IlTAoIkILwrq                   1       wallet             1
# 89313  uA6oXfftGVmT                   1  credit_card             1
# 89314  v3QtU6xlGDJp                   1      voucher             1
# 89315  Xo1fqyXOC6CR                   1  credit_card            10
#
#        payment_value payment_status
# 0             259.14           paid
# 1             382.39           paid
# 2             249.25           paid
# 3              27.79           paid
# 4              76.15           paid
# ...              ...            ...
# 89311         128.00           paid
# 89312         106.86           paid
# 89313         376.39           paid
# 89314          48.05           paid
# 89315         211.93           paid
#
# [89316 rows x 6 columns]

# %%
order_items
# Out:
#            order_id    product_id     seller_id    price  freight_value  \
# 0      Axfy13Hk4PIk  90K0C1fIyQUf  ZWM05J9LcBSF   223.51          84.65
# 1      v6px92oS8cLG  qejhpMGGVcsl  IjlpYfhUbRQs   170.80          23.79
# 2      Ulpf9skrhjfm  qUS5d2pEAyxJ  77p2EYxcM9MD    64.40          17.38
# 3      bwJVWupf2keN  639iGvMyv0De  jWzS0ayv9TGf   264.50          30.72
# 4      Dd0QnrMk9Cj5  1lycYGcsic2F  l1pYW6GBnPMr   779.90          30.66
# ...             ...           ...           ...      ...            ...
# 89311  zlcLnXGgAabl  W8vikEizUggJ  2QjevWskirjm    31.99         188.65
# 89312  IlTAoIkILwrq  KXSbyJWtMMwZ  BFS9XJPapWv0   282.00           1.64
# 89313  uA6oXfftGVmT  EG4wDSpFyTth  TuPm19CMKvrM    58.10           4.09
# 89314  v3QtU6xlGDJp  ZWyg4uNWPHjJ  yGbPyLPc8PmT  2899.00         113.01
# 89315  Xo1fqyXOC6CR  5pbzE0rDy61l  mkWN70fui2ro    37.88          70.06
#
#        quantity
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ...         ...
# 89311         1
# 89312         1
# 89313         1
# 89314         1
# 89315         1
#
# [89316 rows x 6 columns]

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89316 entries, 0 to 89315
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       89316 non-null  object
#  1   customer_id                    89316 non-null  object
#  2   order_status                   89316 non-null  object
#  3   order_purchase_timestamp       89316 non-null  object
#  4   order_approved_at              89307 non-null  object
#  5   order_delivered_timestamp      87427 non-null  object
#  6   order_estimated_delivery_date  89316 non-null  object
# dtypes: object(7)
# memory usage: 4.8+ MB

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89316 entries, 0 to 89315
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               89316 non-null  object
#  1   customer_zip_code_prefix  89316 non-null  int64
#  2   customer_city             89316 non-null  object
#  3   customer_state            89316 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 2.7+ MB

# %%
payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89316 entries, 0 to 89315
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            89316 non-null  object
#  1   payment_sequential  89316 non-null  int64
#  2   payment_type        89316 non-null  object
#  3   installments        89316 non-null  int64
#  4   payment_value       89316 non-null  float64
#  5   payment_status      89316 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 4.1+ MB

# %%
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89316 entries, 0 to 89315
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       89316 non-null  object
#  1   product_id     89316 non-null  object
#  2   seller_id      89316 non-null  object
#  3   price          89316 non-null  float64
#  4   freight_value  89316 non-null  float64
#  5   quantity       89316 non-null  int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27451 entries, 0 to 89315
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      27451 non-null  object
#  1   category        27451 non-null  object
#  2   sub_category    27451 non-null  object
#  3   stock_quantity  27451 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 1.0+ MB

# %%
orders.isnull().sum()
customers.isnull().sum()
payments.isnull().sum()
order_items.isnull().sum()
products.isnull().sum()
# Out:
# product_id        0
# category          0
# sub_category      0
# stock_quantity    0
# dtype: int64

# %%
orders.isna().sum()
customers.isna().sum()
payments.isna().sum()
order_items.isna().sum()
products.isna().sum()
# Out:
# product_id        0
# category          0
# sub_category      0
# stock_quantity    0
# dtype: int64

# %% [markdown]
# ### 1.2 Data Type Conversion and Parsing Dates

# %%
orders['order_purchase_timestamp'] = pd.to_datetime(orders['order_purchase_timestamp'])
orders['order_approved_at'] = pd.to_datetime(orders['order_approved_at'])
orders['order_delivered_timestamp'] = pd.to_datetime(orders['order_delivered_timestamp'])
orders['order_estimated_delivery_date'] = pd.to_datetime(orders['order_estimated_delivery_date'])

# %%
orders
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 0      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1      v6px92oS8cLG  PxA7fv9spyhx    delivered      2018-06-20 21:40:31
# 2      Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered      2018-02-16 16:19:31
# 3      bwJVWupf2keN  EOEsCQ6QlpIg    delivered      2018-08-18 18:04:29
# 4      Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered      2017-12-22 16:44:04
# ...             ...           ...          ...                      ...
# 89311  zlcLnXGgAabl  bfJtzkBGksdY    delivered      2018-08-19 17:25:36
# 89312  IlTAoIkILwrq  4hjsCpj6FC7g    delivered      2017-12-15 11:20:27
# 89313  uA6oXfftGVmT  DLn56oKHl9bv    delivered      2018-07-24 06:39:14
# 89314  v3QtU6xlGDJp  auSfRYUQUOIq    delivered      2018-08-11 08:04:22
# 89315  Xo1fqyXOC6CR  rhevVNXYJnEs    delivered      2018-06-09 21:46:58
#
#         order_approved_at order_delivered_timestamp  \
# 0     2017-10-22 19:14:13       2017-10-26 22:19:52
# 1     2018-06-20 22:20:20       2018-07-03 22:51:22
# 2     2018-02-17 16:15:35       2018-02-27 01:29:50
# 3     2018-08-18 18:15:16       2018-08-27 20:03:51
# 4     2017-12-22 17:31:31       2018-01-05 19:22:49
# ...                   ...                       ...
# 89311 2018-08-21 04:35:30       2018-08-30 14:47:46
# 89312 2017-12-16 02:37:32       2017-12-20 19:23:40
# 89313 2018-07-24 11:20:39       2018-07-27 01:41:40
# 89314 2018-08-11 08:24:40       2018-08-14 21:43:51
# 89315 2018-06-09 22:19:00       2018-06-14 15:03:46
#
#       order_estimated_delivery_date
# 0                        2017-11-09
# 1                        2018-07-24
# 2                        2018-03-08
# 3                        2018-09-19
# 4                        2018-01-18
# ...                             ...
# 89311                    2018-09-04
# 89312                    2018-01-04
# 89313                    2018-08-01
# 89314                    2018-08-17
# 89315                    2018-07-05
#
# [89316 rows x 7 columns]

# %%
payments['payment_value'] = payments['payment_value'].astype(float)
order_items['price'] = order_items['price'].astype(float)

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89316 entries, 0 to 89315
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       89316 non-null  object
#  1   customer_id                    89316 non-null  object
#  2   order_status                   89316 non-null  object
#  3   order_purchase_timestamp       89316 non-null  datetime64[ns]
#  4   order_approved_at              89307 non-null  datetime64[ns]
#  5   order_delivered_timestamp      87427 non-null  datetime64[ns]
#  6   order_estimated_delivery_date  89316 non-null  datetime64[ns]
# dtypes: datetime64[ns](4), object(3)
# memory usage: 4.8+ MB

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89316 entries, 0 to 89315
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               89316 non-null  object
#  1   customer_zip_code_prefix  89316 non-null  int64
#  2   customer_city             89316 non-null  object
#  3   customer_state            89316 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 2.7+ MB

# %%
payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89316 entries, 0 to 89315
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            89316 non-null  object
#  1   payment_sequential  89316 non-null  int64
#  2   payment_type        89316 non-null  object
#  3   installments        89316 non-null  int64
#  4   payment_value       89316 non-null  float64
#  5   payment_status      89316 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 4.1+ MB

# %%
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89316 entries, 0 to 89315
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       89316 non-null  object
#  1   product_id     89316 non-null  object
#  2   seller_id      89316 non-null  object
#  3   price          89316 non-null  float64
#  4   freight_value  89316 non-null  float64
#  5   quantity       89316 non-null  int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27451 entries, 0 to 89315
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      27451 non-null  object
#  1   category        27451 non-null  object
#  2   sub_category    27451 non-null  object
#  3   stock_quantity  27451 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 1.0+ MB

# %% [markdown]
# ### 1.3 Data Integration

# %%
orders_full=orders.merge(customers, on='customer_id', how='left')  
orders_full= orders_full.merge(payments, on='order_id', how='left') 
orders_full=orders_full.merge(order_items, on='order_id', how='left') 
orders_full=orders_full.merge(products, on='product_id', how='left')

# %%
order_item_counts = order_items.groupby('order_id').size().reset_index(name='item_count')
order_item_counts['item_count'].value_counts().head(10)
# Out:
# item_count
# 1    89316
# Name: count, dtype: int64

# %%
orders_full
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 0      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1      v6px92oS8cLG  PxA7fv9spyhx    delivered      2018-06-20 21:40:31
# 2      Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered      2018-02-16 16:19:31
# 3      bwJVWupf2keN  EOEsCQ6QlpIg    delivered      2018-08-18 18:04:29
# 4      Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered      2017-12-22 16:44:04
# ...             ...           ...          ...                      ...
# 89311  zlcLnXGgAabl  bfJtzkBGksdY    delivered      2018-08-19 17:25:36
# 89312  IlTAoIkILwrq  4hjsCpj6FC7g    delivered      2017-12-15 11:20:27
# 89313  uA6oXfftGVmT  DLn56oKHl9bv    delivered      2018-07-24 06:39:14
# 89314  v3QtU6xlGDJp  auSfRYUQUOIq    delivered      2018-08-11 08:04:22
# 89315  Xo1fqyXOC6CR  rhevVNXYJnEs    delivered      2018-06-09 21:46:58
#
#         order_approved_at order_delivered_timestamp  \
# 0     2017-10-22 19:14:13       2017-10-26 22:19:52
# 1     2018-06-20 22:20:20       2018-07-03 22:51:22
# 2     2018-02-17 16:15:35       2018-02-27 01:29:50
# 3     2018-08-18 18:15:16       2018-08-27 20:03:51
# 4     2017-12-22 17:31:31       2018-01-05 19:22:49
# ...                   ...                       ...
# 89311 2018-08-21 04:35:30       2018-08-30 14:47:46
# 89312 2017-12-16 02:37:32       2017-12-20 19:23:40
# 89313 2018-07-24 11:20:39       2018-07-27 01:41:40
# 89314 2018-08-11 08:24:40       2018-08-14 21:43:51
# 89315 2018-06-09 22:19:00       2018-06-14 15:03:46
#
#       order_estimated_delivery_date  customer_zip_code_prefix  \
# 0                        2017-11-09                     58125
# 1                        2018-07-24                      3112
# 2                        2018-03-08                      4119
# 3                        2018-09-19                     18212
# 4                        2018-01-18                     88868
# ...                             ...                       ...
# 89311                    2018-09-04                     94060
# 89312                    2018-01-04                     99835
# 89313                    2018-08-01                      2540
# 89314                    2018-08-17                     12288
# 89315                    2018-07-05                     93048
#
#             customer_city customer_state  ...  payment_value payment_status  \
# 0         varzea paulista             SP  ...         259.14           paid
# 1      armacao dos buzios             RJ  ...         382.39           paid
# 2                 jandira             SP  ...         249.25           paid
# 3              uberlandia             MG  ...          27.79           paid
# 4                ilhabela             SP  ...          76.15           paid
# ...                   ...            ...  ...            ...            ...
# 89311              amparo             SP  ...         128.00           paid
# 89312             itapevi             SP  ...         106.86           paid
# 89313           sao paulo             SP  ...         376.39           paid
# 89314            paulinia             SP  ...          48.05           paid
# 89315            brasilia             DF  ...         211.93           paid
#
#          product_id     seller_id    price freight_value quantity  \
# 0      90K0C1fIyQUf  ZWM05J9LcBSF   223.51         84.65        1
# 1      qejhpMGGVcsl  IjlpYfhUbRQs   170.80         23.79        1
# 2      qUS5d2pEAyxJ  77p2EYxcM9MD    64.40         17.38        1
# 3      639iGvMyv0De  jWzS0ayv9TGf   264.50         30.72        1
# 4      1lycYGcsic2F  l1pYW6GBnPMr   779.90         30.66        1
# ...             ...           ...      ...           ...      ...
# 89311  W8vikEizUggJ  2QjevWskirjm    31.99        188.65        1
# 89312  KXSbyJWtMMwZ  BFS9XJPapWv0   282.00          1.64        1
# 89313  EG4wDSpFyTth  TuPm19CMKvrM    58.10          4.09        1
# 89314  ZWyg4uNWPHjJ  yGbPyLPc8PmT  2899.00        113.01        1
# 89315  5pbzE0rDy61l  mkWN70fui2ro    37.88         70.06        1
#
#           category  sub_category  stock_quantity
# 0             toys          misc              13
# 1          watches         gifts               3
# 2      costruction  tools garden               5
# 3             toys          misc               6
# 4             toys          misc              13
# ...            ...           ...             ...
# 89311         toys          misc               1
# 89312         toys          misc               3
# 89313       health        beauty             206
# 89314         toys          misc             110
# 89315         toys          misc               1
#
# [89316 rows x 23 columns]

# %%
orders_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89316 entries, 0 to 89315
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       89316 non-null  object
#  1   customer_id                    89316 non-null  object
#  2   order_status                   89316 non-null  object
#  3   order_purchase_timestamp       89316 non-null  datetime64[ns]
#  4   order_approved_at              89307 non-null  datetime64[ns]
#  5   order_delivered_timestamp      87427 non-null  datetime64[ns]
#  6   order_estimated_delivery_date  89316 non-null  datetime64[ns]
#  7   customer_zip_code_prefix       89316 non-null  int64
#  8   customer_city                  89316 non-null  object
#  9   customer_state                 89316 non-null  object
#  10  payment_sequential             89316 non-null  int64
#  11  payment_type                   89316 non-null  object
#  12  installments                   89316 non-null  int64
#  13  payment_value                  89316 non-null  float64
#  14  payment_status                 89316 non-null  object
#  15  product_id                     89316 non-null  object
#  16  seller_id                      89316 non-null  object
#  17  price                          89316 non-null  float64
#  18  freight_value                  89316 non-null  float64
#  19  quantity                       89316 non-null  int64
#  20  category                       89316 non-null  object
#  21  sub_category                   89316 non-null  object
#  22  stock_quantity                 89316 non-null  int64
# dtypes: datetime64[ns](4), float64(3), int64(5), object(11)
# memory usage: 15.7+ MB

# %%
orders_full.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                   9
# order_delivered_timestamp        1889
# order_estimated_delivery_date       0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# payment_sequential                  0
# payment_type                        0
# installments                        0
# payment_value                       0
# payment_status                      0
# product_id                          0
# seller_id                           0
# price                               0
# freight_value                       0
# quantity                            0
# category                            0
# sub_category                        0
# stock_quantity                      0
# dtype: int64

# %% [markdown]
# ### 1.4 Feature Engineering

# %%
orders_full['order_date'] = pd.to_datetime(orders_full['order_purchase_timestamp'])
orders_full['order_month'] = orders_full['order_date'].dt.month
orders_full['order_day'] = orders_full['order_date'].dt.day
orders_full['order_hour'] = orders_full['order_date'].dt.hour

# %%
orders_full['order_value'] = orders_full['price'] * orders_full['quantity']

# %%
check = orders_full["price"] - orders_full["order_value"]
check.unique()
# Out:
# array([0.])

# %%
orders_full['shipping_cost_ratio'] = orders_full['freight_value'] / orders_full['order_value']

# %%
orders_full['delivery_time'] = (orders_full['order_delivered_timestamp'] - orders_full['order_approved_at']).dt.days

# %%
orders_full['estimated_vs_actual_delivery'] = orders_full['order_estimated_delivery_date'] - orders_full['order_delivered_timestamp']

# %%
orders_full.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_timestamp',
#        'order_estimated_delivery_date', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state', 'payment_sequential', 'payment_type',
#        'installments', 'payment_value', 'payment_status', 'product_id',
#        'seller_id', 'price', 'freight_value', 'quantity', 'category',
#        'sub_category', 'stock_quantity', 'order_date', 'order_month',
#        'order_day', 'order_hour', 'order_value', 'shipping_cost_ratio',
#        'delivery_time', 'estimated_vs_actual_delivery'],
#       dtype='object')

# %%
orders_full["order_status"].unique()
# Out:
# array(['delivered', 'canceled', 'shipped', 'processing', 'invoiced',
#        'unavailable', 'approved'], dtype=object)

# %%
orders_full.groupby('order_status')['order_delivered_timestamp'].unique()
# Out:
# order_status
# approved                                                   [NaT]
# canceled       [NaT, 2016-11-09 14:53:50, 2016-10-19 18:47:43...
# delivered      [2017-10-26 22:19:52, 2018-07-03 22:51:22, 201...
# invoiced                                                   [NaT]
# processing                                                 [NaT]
# shipped                                                    [NaT]
# unavailable                                                [NaT]
# Name: order_delivered_timestamp, dtype: object

# %%
orders_full
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 0      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1      v6px92oS8cLG  PxA7fv9spyhx    delivered      2018-06-20 21:40:31
# 2      Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered      2018-02-16 16:19:31
# 3      bwJVWupf2keN  EOEsCQ6QlpIg    delivered      2018-08-18 18:04:29
# 4      Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered      2017-12-22 16:44:04
# ...             ...           ...          ...                      ...
# 89311  zlcLnXGgAabl  bfJtzkBGksdY    delivered      2018-08-19 17:25:36
# 89312  IlTAoIkILwrq  4hjsCpj6FC7g    delivered      2017-12-15 11:20:27
# 89313  uA6oXfftGVmT  DLn56oKHl9bv    delivered      2018-07-24 06:39:14
# 89314  v3QtU6xlGDJp  auSfRYUQUOIq    delivered      2018-08-11 08:04:22
# 89315  Xo1fqyXOC6CR  rhevVNXYJnEs    delivered      2018-06-09 21:46:58
#
#         order_approved_at order_delivered_timestamp  \
# 0     2017-10-22 19:14:13       2017-10-26 22:19:52
# 1     2018-06-20 22:20:20       2018-07-03 22:51:22
# 2     2018-02-17 16:15:35       2018-02-27 01:29:50
# 3     2018-08-18 18:15:16       2018-08-27 20:03:51
# 4     2017-12-22 17:31:31       2018-01-05 19:22:49
# ...                   ...                       ...
# 89311 2018-08-21 04:35:30       2018-08-30 14:47:46
# 89312 2017-12-16 02:37:32       2017-12-20 19:23:40
# 89313 2018-07-24 11:20:39       2018-07-27 01:41:40
# 89314 2018-08-11 08:24:40       2018-08-14 21:43:51
# 89315 2018-06-09 22:19:00       2018-06-14 15:03:46
#
#       order_estimated_delivery_date  customer_zip_code_prefix  \
# 0                        2017-11-09                     58125
# 1                        2018-07-24                      3112
# 2                        2018-03-08                      4119
# 3                        2018-09-19                     18212
# 4                        2018-01-18                     88868
# ...                             ...                       ...
# 89311                    2018-09-04                     94060
# 89312                    2018-01-04                     99835
# 89313                    2018-08-01                      2540
# 89314                    2018-08-17                     12288
# 89315                    2018-07-05                     93048
#
#             customer_city customer_state  ...  sub_category stock_quantity  \
# 0         varzea paulista             SP  ...          misc             13
# 1      armacao dos buzios             RJ  ...         gifts              3
# 2                 jandira             SP  ...  tools garden              5
# 3              uberlandia             MG  ...          misc              6
# 4                ilhabela             SP  ...          misc             13
# ...                   ...            ...  ...           ...            ...
# 89311              amparo             SP  ...          misc              1
# 89312             itapevi             SP  ...          misc              3
# 89313           sao paulo             SP  ...        beauty            206
# 89314            paulinia             SP  ...          misc            110
# 89315            brasilia             DF  ...          misc              1
#
#                order_date  order_month order_day order_hour order_value  \
# 0     2017-10-22 18:57:54           10        22         18      223.51
# 1     2018-06-20 21:40:31            6        20         21      170.80
# 2     2018-02-16 16:19:31            2        16         16       64.40
# 3     2018-08-18 18:04:29            8        18         18      264.50
# 4     2017-12-22 16:44:04           12        22         16      779.90
# ...                   ...          ...       ...        ...         ...
# 89311 2018-08-19 17:25:36            8        19         17       31.99
# 89312 2017-12-15 11:20:27           12        15         11      282.00
# 89313 2018-07-24 06:39:14            7        24          6       58.10
# 89314 2018-08-11 08:04:22            8        11          8     2899.00
# 89315 2018-06-09 21:46:58            6         9         21       37.88
#
#        shipping_cost_ratio  delivery_time  estimated_vs_actual_delivery
# 0                 0.378730            4.0              13 days 01:40:08
# 1                 0.139286           13.0              20 days 01:08:38
# 2                 0.269876            9.0               8 days 22:30:10
# 3                 0.116144            9.0              22 days 03:56:09
# 4                 0.039313           14.0              12 days 04:37:11
# ...                    ...            ...                           ...
# 89311             5.897155            9.0               4 days 09:12:14
# 89312             0.005816            4.0              14 days 04:36:20
# 89313             0.070396            2.0               4 days 22:18:20
# 89314             0.038982            3.0               2 days 02:16:09
# 89315             1.849525            4.0              20 days 08:56:14
#
# [89316 rows x 31 columns]

# %% [markdown]
# ### 1.5 Descriptive Statistics

# %%
print("Mean Order Value:", orders_full['order_value'].mean())
print("Median Order Value:", orders_full['order_value'].median())
print("Mode Order Value:", orders_full['order_value'].mode())
# Out:
# Mean Order Value: 340.900542903847
# Median Order Value: 136.9
# Mode Order Value: 0    692.0
# Name: order_value, dtype: float64

# %%
print("Mean Payment Value:", orders_full['payment_value'].mean())
print("Median Payment Value:", orders_full['payment_value'].median())
print("Mode Payment Value:", orders_full['payment_value'].mode())
# Out:
# Mean Payment Value: 268.65718986519767
# Median Payment Value: 171.86
# Mode Payment Value: 0    145.48
# Name: payment_value, dtype: float64

# %%
print("Min Freight Value:", orders_full['freight_value'].min())
print("Max Freight Value:", orders_full['freight_value'].max())
print("Freight Range:", orders_full['freight_value'].max() - orders_full['freight_value'].min())
# Out:
# Min Freight Value: 0.0
# Max Freight Value: 409.68
# Freight Range: 409.68

# %%
print("Min Quantity:", orders_full['installments'].min())
print("Max Quantity:", orders_full['installments'].max())
print("Quantity Range:", orders_full['installments'].max() - orders_full['installments'].min())
# Out:
# Min Quantity: 0
# Max Quantity: 24
# Quantity Range: 24

# %%
print("Std of Freight Value:", orders_full['freight_value'].std())
print("Variance of Freight Value:", orders_full['freight_value'].var())
# Out:
# Std of Freight Value: 37.672491287608494
# Variance of Freight Value: 1419.216599814938

# %%
print("Std of Payment Value:", orders_full['payment_value'].std())
print("Variance of Payment Value:", orders_full['payment_value'].var())
# Out:
# Std of Payment Value: 344.4095661155258
# Variance of Payment Value: 118617.94923188473

# %%
print("Std of Delivery Time:", orders_full['delivery_time'].std())
print("Variance of Delivery Time:", orders_full['delivery_time'].var())
# Out:
# Std of Delivery Time: 9.241673711621615
# Variance of Delivery Time: 85.40853299207804

# %%
print("Unique Products:", orders_full['product_id'].nunique())
print("Unique Categories:", orders_full['category'].nunique())
print("Unique Payment Types:", orders_full['payment_type'].nunique())
print("Unique Order Statuses:", orders_full['order_status'].nunique())
# Out:
# Unique Products: 27451
# Unique Categories: 51
# Unique Payment Types: 4
# Unique Order Statuses: 7

# %%
print("Payment Type Frequency:\n", orders_full['payment_type'].value_counts())
print("Order Status Frequency:\n", orders_full['order_status'].value_counts())
# Out:
# Payment Type Frequency:
#  payment_type
# credit_card    65814
# wallet         17302
# voucher         4911
# debit_card      1289
# Name: count, dtype: int64
# Order Status Frequency:
#  order_status
# delivered      87428
# shipped          936
# canceled         409
# processing       273
# invoiced         266
# unavailable        2
# approved           2
# Name: count, dtype: int64

# %%
print("Skewness - Payment Value:", orders_full['payment_value'].skew())
print("Kurtosis - Payment Value:", orders_full['payment_value'].kurtosis())
# Out:
# Skewness - Payment Value: 4.398856830119261
# Kurtosis - Payment Value: 34.40479858676052

# %%
print("Skewness - Order Value:", orders_full['order_value'].skew())
print("Kurtosis - Order Value:", orders_full['order_value'].kurtosis())
# Out:
# Skewness - Order Value: 3.751492443276309
# Kurtosis - Order Value: 17.077565307554337

# %% [markdown]
# ### 1.6 Handling Missing Values

# %%
orders_full
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 0      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1      v6px92oS8cLG  PxA7fv9spyhx    delivered      2018-06-20 21:40:31
# 2      Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered      2018-02-16 16:19:31
# 3      bwJVWupf2keN  EOEsCQ6QlpIg    delivered      2018-08-18 18:04:29
# 4      Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered      2017-12-22 16:44:04
# ...             ...           ...          ...                      ...
# 89311  zlcLnXGgAabl  bfJtzkBGksdY    delivered      2018-08-19 17:25:36
# 89312  IlTAoIkILwrq  4hjsCpj6FC7g    delivered      2017-12-15 11:20:27
# 89313  uA6oXfftGVmT  DLn56oKHl9bv    delivered      2018-07-24 06:39:14
# 89314  v3QtU6xlGDJp  auSfRYUQUOIq    delivered      2018-08-11 08:04:22
# 89315  Xo1fqyXOC6CR  rhevVNXYJnEs    delivered      2018-06-09 21:46:58
#
#         order_approved_at order_delivered_timestamp  \
# 0     2017-10-22 19:14:13       2017-10-26 22:19:52
# 1     2018-06-20 22:20:20       2018-07-03 22:51:22
# 2     2018-02-17 16:15:35       2018-02-27 01:29:50
# 3     2018-08-18 18:15:16       2018-08-27 20:03:51
# 4     2017-12-22 17:31:31       2018-01-05 19:22:49
# ...                   ...                       ...
# 89311 2018-08-21 04:35:30       2018-08-30 14:47:46
# 89312 2017-12-16 02:37:32       2017-12-20 19:23:40
# 89313 2018-07-24 11:20:39       2018-07-27 01:41:40
# 89314 2018-08-11 08:24:40       2018-08-14 21:43:51
# 89315 2018-06-09 22:19:00       2018-06-14 15:03:46
#
#       order_estimated_delivery_date  customer_zip_code_prefix  \
# 0                        2017-11-09                     58125
# 1                        2018-07-24                      3112
# 2                        2018-03-08                      4119
# 3                        2018-09-19                     18212
# 4                        2018-01-18                     88868
# ...                             ...                       ...
# 89311                    2018-09-04                     94060
# 89312                    2018-01-04                     99835
# 89313                    2018-08-01                      2540
# 89314                    2018-08-17                     12288
# 89315                    2018-07-05                     93048
#
#             customer_city customer_state  ...  sub_category stock_quantity  \
# 0         varzea paulista             SP  ...          misc             13
# 1      armacao dos buzios             RJ  ...         gifts              3
# 2                 jandira             SP  ...  tools garden              5
# 3              uberlandia             MG  ...          misc              6
# 4                ilhabela             SP  ...          misc             13
# ...                   ...            ...  ...           ...            ...
# 89311              amparo             SP  ...          misc              1
# 89312             itapevi             SP  ...          misc              3
# 89313           sao paulo             SP  ...        beauty            206
# 89314            paulinia             SP  ...          misc            110
# 89315            brasilia             DF  ...          misc              1
#
#                order_date  order_month order_day order_hour order_value  \
# 0     2017-10-22 18:57:54           10        22         18      223.51
# 1     2018-06-20 21:40:31            6        20         21      170.80
# 2     2018-02-16 16:19:31            2        16         16       64.40
# 3     2018-08-18 18:04:29            8        18         18      264.50
# 4     2017-12-22 16:44:04           12        22         16      779.90
# ...                   ...          ...       ...        ...         ...
# 89311 2018-08-19 17:25:36            8        19         17       31.99
# 89312 2017-12-15 11:20:27           12        15         11      282.00
# 89313 2018-07-24 06:39:14            7        24          6       58.10
# 89314 2018-08-11 08:04:22            8        11          8     2899.00
# 89315 2018-06-09 21:46:58            6         9         21       37.88
#
#        shipping_cost_ratio  delivery_time  estimated_vs_actual_delivery
# 0                 0.378730            4.0              13 days 01:40:08
# 1                 0.139286           13.0              20 days 01:08:38
# 2                 0.269876            9.0               8 days 22:30:10
# 3                 0.116144            9.0              22 days 03:56:09
# 4                 0.039313           14.0              12 days 04:37:11
# ...                    ...            ...                           ...
# 89311             5.897155            9.0               4 days 09:12:14
# 89312             0.005816            4.0              14 days 04:36:20
# 89313             0.070396            2.0               4 days 22:18:20
# 89314             0.038982            3.0               2 days 02:16:09
# 89315             1.849525            4.0              20 days 08:56:14
#
# [89316 rows x 31 columns]

# %%
orders_full.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                   9
# order_delivered_timestamp        1889
# order_estimated_delivery_date       0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# payment_sequential                  0
# payment_type                        0
# installments                        0
# payment_value                       0
# payment_status                      0
# product_id                          0
# seller_id                           0
# price                               0
# freight_value                       0
# quantity                            0
# category                            0
# sub_category                        0
# stock_quantity                      0
# order_date                          0
# order_month                         0
# order_day                           0
# order_hour                          0
# order_value                         0
# shipping_cost_ratio                 0
# delivery_time                    1898
# estimated_vs_actual_delivery     1889
# dtype: int64

# %%
orders_full['order_status'].unique()
# Out:
# array(['delivered', 'canceled', 'shipped', 'processing', 'invoiced',
#        'unavailable', 'approved'], dtype=object)

# %%
orders_full.loc[
    orders_full['order_status'].isin(['invoiced', 'shipped', 'approved','unavailable', 'processing','canceled']),
    'order_delivered_timestamp'
] = pd.NaT

# %%
orders_full
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 0      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1      v6px92oS8cLG  PxA7fv9spyhx    delivered      2018-06-20 21:40:31
# 2      Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered      2018-02-16 16:19:31
# 3      bwJVWupf2keN  EOEsCQ6QlpIg    delivered      2018-08-18 18:04:29
# 4      Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered      2017-12-22 16:44:04
# ...             ...           ...          ...                      ...
# 89311  zlcLnXGgAabl  bfJtzkBGksdY    delivered      2018-08-19 17:25:36
# 89312  IlTAoIkILwrq  4hjsCpj6FC7g    delivered      2017-12-15 11:20:27
# 89313  uA6oXfftGVmT  DLn56oKHl9bv    delivered      2018-07-24 06:39:14
# 89314  v3QtU6xlGDJp  auSfRYUQUOIq    delivered      2018-08-11 08:04:22
# 89315  Xo1fqyXOC6CR  rhevVNXYJnEs    delivered      2018-06-09 21:46:58
#
#         order_approved_at order_delivered_timestamp  \
# 0     2017-10-22 19:14:13       2017-10-26 22:19:52
# 1     2018-06-20 22:20:20       2018-07-03 22:51:22
# 2     2018-02-17 16:15:35       2018-02-27 01:29:50
# 3     2018-08-18 18:15:16       2018-08-27 20:03:51
# 4     2017-12-22 17:31:31       2018-01-05 19:22:49
# ...                   ...                       ...
# 89311 2018-08-21 04:35:30       2018-08-30 14:47:46
# 89312 2017-12-16 02:37:32       2017-12-20 19:23:40
# 89313 2018-07-24 11:20:39       2018-07-27 01:41:40
# 89314 2018-08-11 08:24:40       2018-08-14 21:43:51
# 89315 2018-06-09 22:19:00       2018-06-14 15:03:46
#
#       order_estimated_delivery_date  customer_zip_code_prefix  \
# 0                        2017-11-09                     58125
# 1                        2018-07-24                      3112
# 2                        2018-03-08                      4119
# 3                        2018-09-19                     18212
# 4                        2018-01-18                     88868
# ...                             ...                       ...
# 89311                    2018-09-04                     94060
# 89312                    2018-01-04                     99835
# 89313                    2018-08-01                      2540
# 89314                    2018-08-17                     12288
# 89315                    2018-07-05                     93048
#
#             customer_city customer_state  ...  sub_category stock_quantity  \
# 0         varzea paulista             SP  ...          misc             13
# 1      armacao dos buzios             RJ  ...         gifts              3
# 2                 jandira             SP  ...  tools garden              5
# 3              uberlandia             MG  ...          misc              6
# 4                ilhabela             SP  ...          misc             13
# ...                   ...            ...  ...           ...            ...
# 89311              amparo             SP  ...          misc              1
# 89312             itapevi             SP  ...          misc              3
# 89313           sao paulo             SP  ...        beauty            206
# 89314            paulinia             SP  ...          misc            110
# 89315            brasilia             DF  ...          misc              1
#
#                order_date  order_month order_day order_hour order_value  \
# 0     2017-10-22 18:57:54           10        22         18      223.51
# 1     2018-06-20 21:40:31            6        20         21      170.80
# 2     2018-02-16 16:19:31            2        16         16       64.40
# 3     2018-08-18 18:04:29            8        18         18      264.50
# 4     2017-12-22 16:44:04           12        22         16      779.90
# ...                   ...          ...       ...        ...         ...
# 89311 2018-08-19 17:25:36            8        19         17       31.99
# 89312 2017-12-15 11:20:27           12        15         11      282.00
# 89313 2018-07-24 06:39:14            7        24          6       58.10
# 89314 2018-08-11 08:04:22            8        11          8     2899.00
# 89315 2018-06-09 21:46:58            6         9         21       37.88
#
#        shipping_cost_ratio  delivery_time  estimated_vs_actual_delivery
# 0                 0.378730            4.0              13 days 01:40:08
# 1                 0.139286           13.0              20 days 01:08:38
# 2                 0.269876            9.0               8 days 22:30:10
# 3                 0.116144            9.0              22 days 03:56:09
# 4                 0.039313           14.0              12 days 04:37:11
# ...                    ...            ...                           ...
# 89311             5.897155            9.0               4 days 09:12:14
# 89312             0.005816            4.0              14 days 04:36:20
# 89313             0.070396            2.0               4 days 22:18:20
# 89314             0.038982            3.0               2 days 02:16:09
# 89315             1.849525            4.0              20 days 08:56:14
#
# [89316 rows x 31 columns]

# %%
orders_full.groupby('order_status')['order_approved_at'].unique()
# Out:
# order_status
# approved              [2017-02-06 20:30:19, 2017-04-30 20:32:41]
# canceled       [2017-07-24 11:50:18, 2017-07-29 13:05:18, 201...
# delivered      [2017-10-22 19:14:13, 2018-06-20 22:20:20, 201...
# invoiced       [2018-08-06 20:30:10, 2017-06-13 15:43:07, 201...
# processing     [2018-02-04 14:35:32, 2017-05-04 16:55:23, 201...
# shipped        [2017-02-04 13:10:38, 2017-05-09 09:35:20, 201...
# unavailable           [2016-10-06 15:55:40, 2016-10-07 18:53:48]
# Name: order_approved_at, dtype: object

# %%
orders_full["order_approved_at"].unique()
# Out:
# <DatetimeArray>
# ['2017-10-22 19:14:13', '2018-06-20 22:20:20', '2018-02-17 16:15:35',
#  '2018-08-18 18:15:16', '2017-12-22 17:31:31', '2017-09-01 14:50:24',
#  '2018-04-24 18:18:18', '2018-02-23 15:16:13', '2017-11-25 04:54:03',
#  '2017-11-30 13:31:19',
#  ...
#  '2017-05-03 15:50:24', '2017-08-17 02:50:17', '2018-02-27 05:30:53',
#  '2017-09-23 10:45:39', '2017-12-29 16:10:27', '2017-03-22 20:23:47',
#  '2018-08-21 04:35:30', '2017-12-16 02:37:32', '2018-07-24 11:20:39',
#  '2018-08-11 08:24:40']
# Length: 68216, dtype: datetime64[ns]

# %%
orders_full
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 0      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1      v6px92oS8cLG  PxA7fv9spyhx    delivered      2018-06-20 21:40:31
# 2      Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered      2018-02-16 16:19:31
# 3      bwJVWupf2keN  EOEsCQ6QlpIg    delivered      2018-08-18 18:04:29
# 4      Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered      2017-12-22 16:44:04
# ...             ...           ...          ...                      ...
# 89311  zlcLnXGgAabl  bfJtzkBGksdY    delivered      2018-08-19 17:25:36
# 89312  IlTAoIkILwrq  4hjsCpj6FC7g    delivered      2017-12-15 11:20:27
# 89313  uA6oXfftGVmT  DLn56oKHl9bv    delivered      2018-07-24 06:39:14
# 89314  v3QtU6xlGDJp  auSfRYUQUOIq    delivered      2018-08-11 08:04:22
# 89315  Xo1fqyXOC6CR  rhevVNXYJnEs    delivered      2018-06-09 21:46:58
#
#         order_approved_at order_delivered_timestamp  \
# 0     2017-10-22 19:14:13       2017-10-26 22:19:52
# 1     2018-06-20 22:20:20       2018-07-03 22:51:22
# 2     2018-02-17 16:15:35       2018-02-27 01:29:50
# 3     2018-08-18 18:15:16       2018-08-27 20:03:51
# 4     2017-12-22 17:31:31       2018-01-05 19:22:49
# ...                   ...                       ...
# 89311 2018-08-21 04:35:30       2018-08-30 14:47:46
# 89312 2017-12-16 02:37:32       2017-12-20 19:23:40
# 89313 2018-07-24 11:20:39       2018-07-27 01:41:40
# 89314 2018-08-11 08:24:40       2018-08-14 21:43:51
# 89315 2018-06-09 22:19:00       2018-06-14 15:03:46
#
#       order_estimated_delivery_date  customer_zip_code_prefix  \
# 0                        2017-11-09                     58125
# 1                        2018-07-24                      3112
# 2                        2018-03-08                      4119
# 3                        2018-09-19                     18212
# 4                        2018-01-18                     88868
# ...                             ...                       ...
# 89311                    2018-09-04                     94060
# 89312                    2018-01-04                     99835
# 89313                    2018-08-01                      2540
# 89314                    2018-08-17                     12288
# 89315                    2018-07-05                     93048
#
#             customer_city customer_state  ...  sub_category stock_quantity  \
# 0         varzea paulista             SP  ...          misc             13
# 1      armacao dos buzios             RJ  ...         gifts              3
# 2                 jandira             SP  ...  tools garden              5
# 3              uberlandia             MG  ...          misc              6
# 4                ilhabela             SP  ...          misc             13
# ...                   ...            ...  ...           ...            ...
# 89311              amparo             SP  ...          misc              1
# 89312             itapevi             SP  ...          misc              3
# 89313           sao paulo             SP  ...        beauty            206
# 89314            paulinia             SP  ...          misc            110
# 89315            brasilia             DF  ...          misc              1
#
#                order_date  order_month order_day order_hour order_value  \
# 0     2017-10-22 18:57:54           10        22         18      223.51
# 1     2018-06-20 21:40:31            6        20         21      170.80
# 2     2018-02-16 16:19:31            2        16         16       64.40
# 3     2018-08-18 18:04:29            8        18         18      264.50
# 4     2017-12-22 16:44:04           12        22         16      779.90
# ...                   ...          ...       ...        ...         ...
# 89311 2018-08-19 17:25:36            8        19         17       31.99
# 89312 2017-12-15 11:20:27           12        15         11      282.00
# 89313 2018-07-24 06:39:14            7        24          6       58.10
# 89314 2018-08-11 08:04:22            8        11          8     2899.00
# 89315 2018-06-09 21:46:58            6         9         21       37.88
#
#        shipping_cost_ratio  delivery_time  estimated_vs_actual_delivery
# 0                 0.378730            4.0              13 days 01:40:08
# 1                 0.139286           13.0              20 days 01:08:38
# 2                 0.269876            9.0               8 days 22:30:10
# 3                 0.116144            9.0              22 days 03:56:09
# 4                 0.039313           14.0              12 days 04:37:11
# ...                    ...            ...                           ...
# 89311             5.897155            9.0               4 days 09:12:14
# 89312             0.005816            4.0              14 days 04:36:20
# 89313             0.070396            2.0               4 days 22:18:20
# 89314             0.038982            3.0               2 days 02:16:09
# 89315             1.849525            4.0              20 days 08:56:14
#
# [89316 rows x 31 columns]

# %%
orders_full.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                   9
# order_delivered_timestamp        1894
# order_estimated_delivery_date       0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# payment_sequential                  0
# payment_type                        0
# installments                        0
# payment_value                       0
# payment_status                      0
# product_id                          0
# seller_id                           0
# price                               0
# freight_value                       0
# quantity                            0
# category                            0
# sub_category                        0
# stock_quantity                      0
# order_date                          0
# order_month                         0
# order_day                           0
# order_hour                          0
# order_value                         0
# shipping_cost_ratio                 0
# delivery_time                    1898
# estimated_vs_actual_delivery     1889
# dtype: int64

# %%
""" #orders_full.loc[
    (orders_full['order_status'].isin(['approved','delivered'])) & 
    (orders_full['order_approved_at'].isna()),
    'order_approved_at'] = orders_full['order_purchase_timestamp'] """
# Out:
# " #orders_full.loc[\n    (orders_full['order_status'].isin(['approved','delivered'])) & \n    (orders_full['order_approved_at'].isna()),\n    'order_approved_at'] = orders_full['order_purchase_timestamp'] "

# %%
""" orders_full.loc[
    (orders_full['order_approved_at'].isna()),
    orders_full['order_status'].isin(['invoiced', 'shipped','unavailable', 'processing','canceled']),
    'order_approved_at'
] = pd.NaT """
# Out:
# " orders_full.loc[\n    (orders_full['order_approved_at'].isna()),\n    orders_full['order_status'].isin(['invoiced', 'shipped','unavailable', 'processing','canceled']),\n    'order_approved_at'\n] = pd.NaT "

# %%
orders_full['delivery_time'] = (orders_full['order_delivered_timestamp'] - orders_full['order_approved_at']).dt.days

# %%
orders_full
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 0      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1      v6px92oS8cLG  PxA7fv9spyhx    delivered      2018-06-20 21:40:31
# 2      Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered      2018-02-16 16:19:31
# 3      bwJVWupf2keN  EOEsCQ6QlpIg    delivered      2018-08-18 18:04:29
# 4      Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered      2017-12-22 16:44:04
# ...             ...           ...          ...                      ...
# 89311  zlcLnXGgAabl  bfJtzkBGksdY    delivered      2018-08-19 17:25:36
# 89312  IlTAoIkILwrq  4hjsCpj6FC7g    delivered      2017-12-15 11:20:27
# 89313  uA6oXfftGVmT  DLn56oKHl9bv    delivered      2018-07-24 06:39:14
# 89314  v3QtU6xlGDJp  auSfRYUQUOIq    delivered      2018-08-11 08:04:22
# 89315  Xo1fqyXOC6CR  rhevVNXYJnEs    delivered      2018-06-09 21:46:58
#
#         order_approved_at order_delivered_timestamp  \
# 0     2017-10-22 19:14:13       2017-10-26 22:19:52
# 1     2018-06-20 22:20:20       2018-07-03 22:51:22
# 2     2018-02-17 16:15:35       2018-02-27 01:29:50
# 3     2018-08-18 18:15:16       2018-08-27 20:03:51
# 4     2017-12-22 17:31:31       2018-01-05 19:22:49
# ...                   ...                       ...
# 89311 2018-08-21 04:35:30       2018-08-30 14:47:46
# 89312 2017-12-16 02:37:32       2017-12-20 19:23:40
# 89313 2018-07-24 11:20:39       2018-07-27 01:41:40
# 89314 2018-08-11 08:24:40       2018-08-14 21:43:51
# 89315 2018-06-09 22:19:00       2018-06-14 15:03:46
#
#       order_estimated_delivery_date  customer_zip_code_prefix  \
# 0                        2017-11-09                     58125
# 1                        2018-07-24                      3112
# 2                        2018-03-08                      4119
# 3                        2018-09-19                     18212
# 4                        2018-01-18                     88868
# ...                             ...                       ...
# 89311                    2018-09-04                     94060
# 89312                    2018-01-04                     99835
# 89313                    2018-08-01                      2540
# 89314                    2018-08-17                     12288
# 89315                    2018-07-05                     93048
#
#             customer_city customer_state  ...  sub_category stock_quantity  \
# 0         varzea paulista             SP  ...          misc             13
# 1      armacao dos buzios             RJ  ...         gifts              3
# 2                 jandira             SP  ...  tools garden              5
# 3              uberlandia             MG  ...          misc              6
# 4                ilhabela             SP  ...          misc             13
# ...                   ...            ...  ...           ...            ...
# 89311              amparo             SP  ...          misc              1
# 89312             itapevi             SP  ...          misc              3
# 89313           sao paulo             SP  ...        beauty            206
# 89314            paulinia             SP  ...          misc            110
# 89315            brasilia             DF  ...          misc              1
#
#                order_date  order_month order_day order_hour order_value  \
# 0     2017-10-22 18:57:54           10        22         18      223.51
# 1     2018-06-20 21:40:31            6        20         21      170.80
# 2     2018-02-16 16:19:31            2        16         16       64.40
# 3     2018-08-18 18:04:29            8        18         18      264.50
# 4     2017-12-22 16:44:04           12        22         16      779.90
# ...                   ...          ...       ...        ...         ...
# 89311 2018-08-19 17:25:36            8        19         17       31.99
# 89312 2017-12-15 11:20:27           12        15         11      282.00
# 89313 2018-07-24 06:39:14            7        24          6       58.10
# 89314 2018-08-11 08:04:22            8        11          8     2899.00
# 89315 2018-06-09 21:46:58            6         9         21       37.88
#
#        shipping_cost_ratio  delivery_time  estimated_vs_actual_delivery
# 0                 0.378730            4.0              13 days 01:40:08
# 1                 0.139286           13.0              20 days 01:08:38
# 2                 0.269876            9.0               8 days 22:30:10
# 3                 0.116144            9.0              22 days 03:56:09
# 4                 0.039313           14.0              12 days 04:37:11
# ...                    ...            ...                           ...
# 89311             5.897155            9.0               4 days 09:12:14
# 89312             0.005816            4.0              14 days 04:36:20
# 89313             0.070396            2.0               4 days 22:18:20
# 89314             0.038982            3.0               2 days 02:16:09
# 89315             1.849525            4.0              20 days 08:56:14
#
# [89316 rows x 31 columns]

# %%
x = orders_full.select_dtypes(include='datetime')
orders_full[x.columns] = x.fillna(pd.NaT)

# %%
orders_full.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                   9
# order_delivered_timestamp        1894
# order_estimated_delivery_date       0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# payment_sequential                  0
# payment_type                        0
# installments                        0
# payment_value                       0
# payment_status                      0
# product_id                          0
# seller_id                           0
# price                               0
# freight_value                       0
# quantity                            0
# category                            0
# sub_category                        0
# stock_quantity                      0
# order_date                          0
# order_month                         0
# order_day                           0
# order_hour                          0
# order_value                         0
# shipping_cost_ratio                 0
# delivery_time                    1903
# estimated_vs_actual_delivery     1889
# dtype: int64

# %%
orders_full
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 0      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1      v6px92oS8cLG  PxA7fv9spyhx    delivered      2018-06-20 21:40:31
# 2      Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered      2018-02-16 16:19:31
# 3      bwJVWupf2keN  EOEsCQ6QlpIg    delivered      2018-08-18 18:04:29
# 4      Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered      2017-12-22 16:44:04
# ...             ...           ...          ...                      ...
# 89311  zlcLnXGgAabl  bfJtzkBGksdY    delivered      2018-08-19 17:25:36
# 89312  IlTAoIkILwrq  4hjsCpj6FC7g    delivered      2017-12-15 11:20:27
# 89313  uA6oXfftGVmT  DLn56oKHl9bv    delivered      2018-07-24 06:39:14
# 89314  v3QtU6xlGDJp  auSfRYUQUOIq    delivered      2018-08-11 08:04:22
# 89315  Xo1fqyXOC6CR  rhevVNXYJnEs    delivered      2018-06-09 21:46:58
#
#         order_approved_at order_delivered_timestamp  \
# 0     2017-10-22 19:14:13       2017-10-26 22:19:52
# 1     2018-06-20 22:20:20       2018-07-03 22:51:22
# 2     2018-02-17 16:15:35       2018-02-27 01:29:50
# 3     2018-08-18 18:15:16       2018-08-27 20:03:51
# 4     2017-12-22 17:31:31       2018-01-05 19:22:49
# ...                   ...                       ...
# 89311 2018-08-21 04:35:30       2018-08-30 14:47:46
# 89312 2017-12-16 02:37:32       2017-12-20 19:23:40
# 89313 2018-07-24 11:20:39       2018-07-27 01:41:40
# 89314 2018-08-11 08:24:40       2018-08-14 21:43:51
# 89315 2018-06-09 22:19:00       2018-06-14 15:03:46
#
#       order_estimated_delivery_date  customer_zip_code_prefix  \
# 0                        2017-11-09                     58125
# 1                        2018-07-24                      3112
# 2                        2018-03-08                      4119
# 3                        2018-09-19                     18212
# 4                        2018-01-18                     88868
# ...                             ...                       ...
# 89311                    2018-09-04                     94060
# 89312                    2018-01-04                     99835
# 89313                    2018-08-01                      2540
# 89314                    2018-08-17                     12288
# 89315                    2018-07-05                     93048
#
#             customer_city customer_state  ...  sub_category stock_quantity  \
# 0         varzea paulista             SP  ...          misc             13
# 1      armacao dos buzios             RJ  ...         gifts              3
# 2                 jandira             SP  ...  tools garden              5
# 3              uberlandia             MG  ...          misc              6
# 4                ilhabela             SP  ...          misc             13
# ...                   ...            ...  ...           ...            ...
# 89311              amparo             SP  ...          misc              1
# 89312             itapevi             SP  ...          misc              3
# 89313           sao paulo             SP  ...        beauty            206
# 89314            paulinia             SP  ...          misc            110
# 89315            brasilia             DF  ...          misc              1
#
#                order_date  order_month order_day order_hour order_value  \
# 0     2017-10-22 18:57:54           10        22         18      223.51
# 1     2018-06-20 21:40:31            6        20         21      170.80
# 2     2018-02-16 16:19:31            2        16         16       64.40
# 3     2018-08-18 18:04:29            8        18         18      264.50
# 4     2017-12-22 16:44:04           12        22         16      779.90
# ...                   ...          ...       ...        ...         ...
# 89311 2018-08-19 17:25:36            8        19         17       31.99
# 89312 2017-12-15 11:20:27           12        15         11      282.00
# 89313 2018-07-24 06:39:14            7        24          6       58.10
# 89314 2018-08-11 08:04:22            8        11          8     2899.00
# 89315 2018-06-09 21:46:58            6         9         21       37.88
#
#        shipping_cost_ratio  delivery_time  estimated_vs_actual_delivery
# 0                 0.378730            4.0              13 days 01:40:08
# 1                 0.139286           13.0              20 days 01:08:38
# 2                 0.269876            9.0               8 days 22:30:10
# 3                 0.116144            9.0              22 days 03:56:09
# 4                 0.039313           14.0              12 days 04:37:11
# ...                    ...            ...                           ...
# 89311             5.897155            9.0               4 days 09:12:14
# 89312             0.005816            4.0              14 days 04:36:20
# 89313             0.070396            2.0               4 days 22:18:20
# 89314             0.038982            3.0               2 days 02:16:09
# 89315             1.849525            4.0              20 days 08:56:14
#
# [89316 rows x 31 columns]

# %%
orders_full.reset_index(inplace=True)

# %%
orders_full
# Out:
#        index      order_id   customer_id order_status  \
# 0          0  Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered
# 1          1  v6px92oS8cLG  PxA7fv9spyhx    delivered
# 2          2  Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered
# 3          3  bwJVWupf2keN  EOEsCQ6QlpIg    delivered
# 4          4  Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered
# ...      ...           ...           ...          ...
# 89311  89311  zlcLnXGgAabl  bfJtzkBGksdY    delivered
# 89312  89312  IlTAoIkILwrq  4hjsCpj6FC7g    delivered
# 89313  89313  uA6oXfftGVmT  DLn56oKHl9bv    delivered
# 89314  89314  v3QtU6xlGDJp  auSfRYUQUOIq    delivered
# 89315  89315  Xo1fqyXOC6CR  rhevVNXYJnEs    delivered
#
#       order_purchase_timestamp   order_approved_at order_delivered_timestamp  \
# 0          2017-10-22 18:57:54 2017-10-22 19:14:13       2017-10-26 22:19:52
# 1          2018-06-20 21:40:31 2018-06-20 22:20:20       2018-07-03 22:51:22
# 2          2018-02-16 16:19:31 2018-02-17 16:15:35       2018-02-27 01:29:50
# 3          2018-08-18 18:04:29 2018-08-18 18:15:16       2018-08-27 20:03:51
# 4          2017-12-22 16:44:04 2017-12-22 17:31:31       2018-01-05 19:22:49
# ...                        ...                 ...                       ...
# 89311      2018-08-19 17:25:36 2018-08-21 04:35:30       2018-08-30 14:47:46
# 89312      2017-12-15 11:20:27 2017-12-16 02:37:32       2017-12-20 19:23:40
# 89313      2018-07-24 06:39:14 2018-07-24 11:20:39       2018-07-27 01:41:40
# 89314      2018-08-11 08:04:22 2018-08-11 08:24:40       2018-08-14 21:43:51
# 89315      2018-06-09 21:46:58 2018-06-09 22:19:00       2018-06-14 15:03:46
#
#       order_estimated_delivery_date  customer_zip_code_prefix  \
# 0                        2017-11-09                     58125
# 1                        2018-07-24                      3112
# 2                        2018-03-08                      4119
# 3                        2018-09-19                     18212
# 4                        2018-01-18                     88868
# ...                             ...                       ...
# 89311                    2018-09-04                     94060
# 89312                    2018-01-04                     99835
# 89313                    2018-08-01                      2540
# 89314                    2018-08-17                     12288
# 89315                    2018-07-05                     93048
#
#             customer_city  ...  sub_category  stock_quantity  \
# 0         varzea paulista  ...          misc              13
# 1      armacao dos buzios  ...         gifts               3
# 2                 jandira  ...  tools garden               5
# 3              uberlandia  ...          misc               6
# 4                ilhabela  ...          misc              13
# ...                   ...  ...           ...             ...
# 89311              amparo  ...          misc               1
# 89312             itapevi  ...          misc               3
# 89313           sao paulo  ...        beauty             206
# 89314            paulinia  ...          misc             110
# 89315            brasilia  ...          misc               1
#
#                order_date  order_month  order_day order_hour order_value  \
# 0     2017-10-22 18:57:54           10         22         18      223.51
# 1     2018-06-20 21:40:31            6         20         21      170.80
# 2     2018-02-16 16:19:31            2         16         16       64.40
# 3     2018-08-18 18:04:29            8         18         18      264.50
# 4     2017-12-22 16:44:04           12         22         16      779.90
# ...                   ...          ...        ...        ...         ...
# 89311 2018-08-19 17:25:36            8         19         17       31.99
# 89312 2017-12-15 11:20:27           12         15         11      282.00
# 89313 2018-07-24 06:39:14            7         24          6       58.10
# 89314 2018-08-11 08:04:22            8         11          8     2899.00
# 89315 2018-06-09 21:46:58            6          9         21       37.88
#
#       shipping_cost_ratio  delivery_time  estimated_vs_actual_delivery
# 0                0.378730            4.0              13 days 01:40:08
# 1                0.139286           13.0              20 days 01:08:38
# 2                0.269876            9.0               8 days 22:30:10
# 3                0.116144            9.0              22 days 03:56:09
# 4                0.039313           14.0              12 days 04:37:11
# ...                   ...            ...                           ...
# 89311            5.897155            9.0               4 days 09:12:14
# 89312            0.005816            4.0              14 days 04:36:20
# 89313            0.070396            2.0               4 days 22:18:20
# 89314            0.038982            3.0               2 days 02:16:09
# 89315            1.849525            4.0              20 days 08:56:14
#
# [89316 rows x 32 columns]

# %%
orders_full = orders_full.drop(columns=["index"])
orders_full
# Out:
#            order_id   customer_id order_status order_purchase_timestamp  \
# 0      Axfy13Hk4PIk  hCT0x9JiGXBQ    delivered      2017-10-22 18:57:54
# 1      v6px92oS8cLG  PxA7fv9spyhx    delivered      2018-06-20 21:40:31
# 2      Ulpf9skrhjfm  g3nXeJkGI0Qw    delivered      2018-02-16 16:19:31
# 3      bwJVWupf2keN  EOEsCQ6QlpIg    delivered      2018-08-18 18:04:29
# 4      Dd0QnrMk9Cj5  mVz5LO2Vd6cL    delivered      2017-12-22 16:44:04
# ...             ...           ...          ...                      ...
# 89311  zlcLnXGgAabl  bfJtzkBGksdY    delivered      2018-08-19 17:25:36
# 89312  IlTAoIkILwrq  4hjsCpj6FC7g    delivered      2017-12-15 11:20:27
# 89313  uA6oXfftGVmT  DLn56oKHl9bv    delivered      2018-07-24 06:39:14
# 89314  v3QtU6xlGDJp  auSfRYUQUOIq    delivered      2018-08-11 08:04:22
# 89315  Xo1fqyXOC6CR  rhevVNXYJnEs    delivered      2018-06-09 21:46:58
#
#         order_approved_at order_delivered_timestamp  \
# 0     2017-10-22 19:14:13       2017-10-26 22:19:52
# 1     2018-06-20 22:20:20       2018-07-03 22:51:22
# 2     2018-02-17 16:15:35       2018-02-27 01:29:50
# 3     2018-08-18 18:15:16       2018-08-27 20:03:51
# 4     2017-12-22 17:31:31       2018-01-05 19:22:49
# ...                   ...                       ...
# 89311 2018-08-21 04:35:30       2018-08-30 14:47:46
# 89312 2017-12-16 02:37:32       2017-12-20 19:23:40
# 89313 2018-07-24 11:20:39       2018-07-27 01:41:40
# 89314 2018-08-11 08:24:40       2018-08-14 21:43:51
# 89315 2018-06-09 22:19:00       2018-06-14 15:03:46
#
#       order_estimated_delivery_date  customer_zip_code_prefix  \
# 0                        2017-11-09                     58125
# 1                        2018-07-24                      3112
# 2                        2018-03-08                      4119
# 3                        2018-09-19                     18212
# 4                        2018-01-18                     88868
# ...                             ...                       ...
# 89311                    2018-09-04                     94060
# 89312                    2018-01-04                     99835
# 89313                    2018-08-01                      2540
# 89314                    2018-08-17                     12288
# 89315                    2018-07-05                     93048
#
#             customer_city customer_state  ...  sub_category stock_quantity  \
# 0         varzea paulista             SP  ...          misc             13
# 1      armacao dos buzios             RJ  ...         gifts              3
# 2                 jandira             SP  ...  tools garden              5
# 3              uberlandia             MG  ...          misc              6
# 4                ilhabela             SP  ...          misc             13
# ...                   ...            ...  ...           ...            ...
# 89311              amparo             SP  ...          misc              1
# 89312             itapevi             SP  ...          misc              3
# 89313           sao paulo             SP  ...        beauty            206
# 89314            paulinia             SP  ...          misc            110
# 89315            brasilia             DF  ...          misc              1
#
#                order_date  order_month order_day order_hour order_value  \
# 0     2017-10-22 18:57:54           10        22         18      223.51
# 1     2018-06-20 21:40:31            6        20         21      170.80
# 2     2018-02-16 16:19:31            2        16         16       64.40
# 3     2018-08-18 18:04:29            8        18         18      264.50
# 4     2017-12-22 16:44:04           12        22         16      779.90
# ...                   ...          ...       ...        ...         ...
# 89311 2018-08-19 17:25:36            8        19         17       31.99
# 89312 2017-12-15 11:20:27           12        15         11      282.00
# 89313 2018-07-24 06:39:14            7        24          6       58.10
# 89314 2018-08-11 08:04:22            8        11          8     2899.00
# 89315 2018-06-09 21:46:58            6         9         21       37.88
#
#        shipping_cost_ratio  delivery_time  estimated_vs_actual_delivery
# 0                 0.378730            4.0              13 days 01:40:08
# 1                 0.139286           13.0              20 days 01:08:38
# 2                 0.269876            9.0               8 days 22:30:10
# 3                 0.116144            9.0              22 days 03:56:09
# 4                 0.039313           14.0              12 days 04:37:11
# ...                    ...            ...                           ...
# 89311             5.897155            9.0               4 days 09:12:14
# 89312             0.005816            4.0              14 days 04:36:20
# 89313             0.070396            2.0               4 days 22:18:20
# 89314             0.038982            3.0               2 days 02:16:09
# 89315             1.849525            4.0              20 days 08:56:14
#
# [89316 rows x 31 columns]

# %%
orders_full.to_csv("mergedData.csv",index=False)
